# %% [markdown]
# # Seaborn練習問題

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams['savefig.bbox'] = 'tight'

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd

# %% [markdown]
# ---
# ## 線グラフ

# %% [markdown]
# ---
# ### 練習問題1
#
# `practice-dt1.pkl` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="whitegrid"`
# - 使用関数：`lineplot()`
# - 色：`tab10`
# - 線の幅：`2.5`
#
# ![download.png](attachment:294e7e4d-60be-4bfc-9561-e6d347e0a6da.png)

# %% [markdown]
# ---
# ### 練習問題2
#
# `dots.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="ticks"`
# - 色：`sns.color_palette("rocket_r")`
# - 高さの値：`5`
# - アスペクト比：`.75`
#
# ![download.png](attachment:59e62cfa-ef1a-4ffe-bc40-d51d93b3632f.png)

# %% [markdown]
# ---
# ## 散布図

# %% [markdown]
# ---
# ### 練習問題3
#
# `mpg.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="white"`
# - 図のサイズ：`5 * 5`
# - 色：`"muted"`
# - 透過度：`.5`
# - サイズ最小値：`40`
# - サイズ最大値：`400`
#
# ![download.png](attachment:e467329b-5fbd-4116-8662-76e30df3ec60.png)

# %% [markdown]
# ---
# ### 練習問題4
#
# `diamonds.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 図の大きさ：`6.5 * 6.5`
# - 色：`"ch:r=-.2,d=.3_r"`
# - サイズ最小値：`1`
# - サイズ最大値：`8`
# - 線の幅：`0`
# - 図の左と下の枠線を消す
#
# ![download.png](attachment:d1fa0bc1-6d12-4312-b016-277a268a5e2c.png)

# %% [markdown]
# ---
# ### 練習問題5
#
# `planets.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 色：`sns.cubehelix_palette(rot=-.2, as_cmap=True)`
# - サイズ最小値：`10`
# - サイズ最大値：`200`
# - x軸とy軸をlog表記にする
# - x軸とy軸のminorの目盛りに線を引く（線の幅：`.25`）
# - 図の左と下の枠線を消す
#
# ![download.png](attachment:272d59ad-b500-4af8-8a0f-61fb783e8dc3.png)

# %% [markdown]
# ---
# ## ヒストグラム

# %% [markdown]
# ---
# ### 練習問題6
#
# `penguins.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - ビンの幅：`3`
# - 各図の高さ：`3`
# - 行変数のタイトルは最後の列の右側に描画する（完成予想図の右側、sex=MALE, sex=FEMALE のような表記）
#
# ![download.png](attachment:f4dc7e49-ed9f-4e37-b3e7-19ba2b214479.png)

# %% [markdown]
# ---
# ### 練習問題7
#
# `diamonds.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="whitegrid"`
# - 色：`"ch:rot=-.25, hue=1, light=.75"`
# - 図の高さ：`6`
# - 各群について正規化して累積分布関数を推定し、各領域を塗りつぶす
#
# ![download.png](attachment:0aa3690b-396e-42ca-a0a3-bc03756cd7cc.png)

# %% [markdown]
# ---
# ### 練習問題8
#
# `mpg.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 入力色：`(250, 70, 50), (350, 70, 50)`
# - 色空間：`"husl"`
# - 各図のアスペクト比：`.75`
# - 線の幅：2
#
# ![download.png](attachment:626ce305-b9c4-4b24-b6ca-6a9daff7b467.png)

# %% [markdown]
# ---
# ### 練習問題9
#
# `diamonds.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - x軸をlogスケールにする
# - 図を4つ横に並べたら折り返す
# - 各図の高さ：`3`
# - 各図のアスペクト比：`.7`
# - 線の幅：2
#
# ![download.png](attachment:282e15da-e5c9-4b0c-9740-d0bb1b2bc95e.png)

# %% [markdown]
# ---
# ### 練習問題10
#
# `practice-dt3.pkl` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 散布図を6角形で描画する
# - 色：`"#4CB391"`
#
# ![download.png](attachment:9e0a86bc-ca3e-42f0-b413-fef4a8703a73.png)

# %% [markdown]
# ---
# ### 練習問題11
#
# `tips.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 散布図に対して回帰直線を描画する
# - 回帰直線はデータの終わりで途切れさせない（図めいっぱいまで描画する）
# - x軸とy軸の範囲を指定する
# - 色：`"m"`
# - 図の高さ：7
#
# ![download.png](attachment:8df6220f-2b51-463f-9342-f23e19621cf2.png)

# %% [markdown]
# ---
# ## 蜂群図

# %% [markdown]
# ---
# ### 練習問題12
#
# `penguins.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="whitegrid", palette="muted"`
# - 使用する関数：`swarmplot()`
# - y軸のラベルを表示しない
# - 性別がわかるデータのみ描画する
#
# ![download.png](attachment:4788d616-d993-4f86-9b4e-869aeac57664.png)

# %% [markdown]
# ---
# ## 棒グラフ

# %% [markdown]
# ---
# ### 練習問題13
#
# `penguins.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - エラーバーを標準偏差として描画する
# - 色：`"dark"`
# - 透過度：`.7`
# - 図の高さ：`5`
# - 図の左の枠線を描画しない
# - タイトルとx軸のラベルを表示しない
#
# ![download.png](attachment:a14b7234-776e-47bc-9cc1-2297c61ec5f2.png)

# %% [markdown]
# ---
# ## 箱ひげ図

# %% [markdown]
# ---
# ### 練習問題14
#
# `tips.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 色：`"pastel"`カラーパレットの`"m"`と`"g"`
# - 図の上と右の枠線を描画しない
# - 左と下の枠線は繋がずに、箱ひげ図からそれぞれ`10`ポイント遠ざける
#
# ![download.png](attachment:3119e4d5-4ed0-46fa-beec-c66494fc6f36.png)

# %% [markdown]
# ---
# ## バイオリン図

# %% [markdown]
# ---
# ### 練習問題15
#
# `tips.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - Yesの色：`"b"`
# - Noの色：`".85"`
# - smoker別に左右でバイオリンを分割する
# - 各バイオリン図の中に四分位を表す線を描く
# - 線の幅：`1`
# - 図の左の枠線を描画しない
#
# ![download.png](attachment:dcfcf701-3f5c-4600-a7c7-31b4964f255c.png)

# %% [markdown]
# ---
# ## 拡張箱ひげ図

# %% [markdown]
# ---
# ### 練習問題16
#
# `diamonds.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 色：`"b"`
# - 各箱の幅を線形にスケールする
# - y軸の下限を0に、上限はデータに依存させる（コードで指定しない）
#
# ![download.png](attachment:862f1b27-0bca-461f-803a-ac7db87ca1df.png)

# %% [markdown]
# ---
# ## ポイントプロット

# %% [markdown]
# ---
# ### 練習問題17
#
# `exercise.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 色：`"YlGnBu_d"`
# - エラーバーを標準偏差として描画する
# - エラーバーのキャップの長さ：`.15`
# - 図の高さ：`5`
# - アスペクト比：`.75`
#
# ![download.png](attachment:07d37edc-c5ca-4223-8f29-a3425683c8e3.png)

# %% [markdown]
# ---
# ## ヒートマップ

# %% [markdown]
# ---
# ### 練習問題
#
# `flights.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 図の大きさ：`9 * 6`
# - 各セルに値を整数で書き込む
# - 線の幅：`.5`
#
# ![download.png](attachment:5e5341be-08ed-47d3-8057-17049e7d5dc1.png)

# %% [markdown]
# ---
# ## Advance

# %% [markdown]
# ---
# ### 練習問題A
#
# `practice-dt2.pkl` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - テーマ：`style="dark"`
# - 図のサイズ：`5 * 5`
# - 使用関数1：`scatterplot()`
#     - 色：`".15"`
#     - 点のサイズ：`5`
# - 使用関数2：`histplot()`
#     - 色：`"mako"`
#     - ビン数：50
#     - 描画閾値割合：`.1`
# - 使用関数3：`kdeplot()`
#     - 色：`"w"`
#     - 等高線の数：`5`
#     - 線の幅：`1`
#
# ![download.png](attachment:b84d830d-619c-4efa-b52e-bd106a46fa3a.png)

# %% [markdown]
# ---
# ### 練習問題B
#
# `diamonds.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 使用する関数：`histplot()`
# - 図の大きさ：`(7, 5)`
# - 図の上と右の境界線を外す
# - 色：`"light:b_r"`
# - ヒストグラムの境界線色：`".3"`
# - ヒストグラムの境界線幅：`.5`
# - x軸をlogスケールにするが、表示する数字は[500, 1000, 2000, 5000, 10000]とする
#
# ![download.png](attachment:ffca16c7-4c74-4c2c-84a3-469a405a3114.png)

# %% [markdown]
# ---
# ### 練習問題C
#
# `car_crashes.csv` より以下の図を作成し、任意の名前で`png`形式で保存してください。
# グラフのタイトル、x軸、y軸のラベル、凡例、グリッド等の外観については、以下に示す情報と完成予想図を参考にしてください。
#
# - 図の大きさ：`(6, 15)`
# - `barplot()`を二回呼び出し、Totalとその内のalcohol-involvedを示す
# - Totalの色：`pastel`カラーパレットの青
# - Alcohol-involvedの色：`muted`カラーパレットの青
# - 図の左と下の枠線を描画しない
# - y軸のラベルを表示しない
#
# ![download.png](attachment:c599511d-d82d-4c72-871b-05b06b8ffa97.png)
